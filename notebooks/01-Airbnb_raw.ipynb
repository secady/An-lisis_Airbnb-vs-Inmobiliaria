# %% [markdown]
# #### Importar todas las librerías necesarias

# %%
import pandas as pd

# %% [markdown]
# #### Importar todos los archivos de listings

# %%
list_bcn = pd.read_csv(r"Datasets\barcelona_listings.csv")
list_bcn.insert(0, "timestamp_date", "2022-12-11")
list_bcn.insert(1, "city", "Barcelona")
list_bcn.head()
# Out:
#   timestamp_date       city     id  \
# 0     2022-12-11  Barcelona  18674
# 1     2022-12-11  Barcelona  23197
# 2     2022-12-11  Barcelona  32711
# 3     2022-12-11  Barcelona  34981
# 4     2022-12-11  Barcelona  36763
#
#                                               name  host_id         host_name  \
# 0  Huge flat for 8 people close to Sagrada Familia    71615  Mireia And Maria
# 1  Forum CCIB DeLuxe, Spacious, Elegant ,Christmas    90417    Etain (Marnie)
# 2                 Sagrada Familia area - Còrsega 1   135703              Nick
# 3             VIDRE HOME PLAZA REAL on LAS RAMBLAS    73163            Andres
# 4                            In front of the beach   158596             Ester
#
#   neighbourhood_group                       neighbourhood  latitude  \
# 0            Eixample                  la Sagrada Família  41.40556
# 1          Sant Martí               el Besòs i el Maresme  41.41243
# 2              Gràcia  el Camp d'en Grassot i Gràcia Nova  41.40566
# ...

# %%
list_eus = pd.read_csv(r"Datasets\euskadi_listings.csv")
list_eus.insert(0, "timestamp_date", "2022-12-30")
list_eus.insert(1, "city", "Euskadi")
list_eus.head()
# Out:
#   timestamp_date     city       id  \
# 0     2022-12-30  Euskadi   132068
# 1     2022-12-30  Euskadi  1311566
# 2     2022-12-30  Euskadi   142760
# 3     2022-12-30  Euskadi  1318286
# 4     2022-12-30  Euskadi   309802
#
#                                                 name  host_id  host_name  \
# 0  Great attic+terrace+parking. Beach views. ESS0...   648938      Mikel
# 1         Habitación con baño exclusivo. Casco Viejo  7127707    Eugenio
# 2             Piso en la playa cerca de Gaztelugatxe   693119    Maitane
# 3                                Room in Bilbao+WIFI  7174903  Jose Luis
# 4                Luxury w/terrace near the beach WIF  1589633        Emy
#
#   neighbourhood_group            neighbourhood  latitude  longitude  \
# 0          GuipÃºzcoa  Donostia-San SebastiÃ¡n  43.32520   -1.97209
# 1             Vizcaya                   Bilbao  43.25892   -2.91867
# 2             Vizcaya                 Busturia  43.39062   -2.69470
# ...

# %%
list_gir = pd.read_csv(r"Datasets\girona_listings.csv")
list_gir.insert(0, "timestamp_date", "2022-12-30")
list_gir.insert(1, "city", "Girona")
list_gir.head()
# Out:
#   timestamp_date    city     id  \
# 0     2022-12-30  Girona  14551
# 1     2022-12-30  Girona  41342
# 2     2022-12-30  Girona  45400
# 3     2022-12-30  Girona  48764
# 4     2022-12-30  Girona  93343
#
#                                                 name  host_id     host_name  \
# 0           Cozy & Colorful by Nature (Private Room)    57237           Mun
# 1                  Beachfront Tamariua (Costa Brava)   180072        Marisa
# 2                 Begur - Loft - Costa Brava - SPAIN   201228         Oscar
# 3                18th C Stone House near Costa Brava   220145  Dick And Ann
# 4  Alquiler de casa en La Costa Brava cerca de playa   477826     Francisco
#
#    neighbourhood_group        neighbourhood  latitude  longitude  \
# 0                  NaN               Girona  41.99650    2.83646
# 1                  NaN  El Port de la Selva  42.34655    3.20463
# 2                  NaN                Begur  41.95577    3.21096
# ...

# %%
list_mad = pd.read_csv(r"Datasets\madrid_listings.csv")
list_mad.insert(0, "timestamp_date", "2022-12-13")
list_mad.insert(1, "city", "Madrid")
list_mad.head()
# Out:
#   timestamp_date    city     id                                      name  \
# 0     2022-12-13  Madrid   6369  Rooftop terrace room ,  ensuite bathroom
# 1     2022-12-13  Madrid  21853                      Bright and airy room
# 2     2022-12-13  Madrid  24805                    Gran Via Studio Madrid
# 3     2022-12-13  Madrid  26825        Single Room whith private Bathroom
# 4     2022-12-13  Madrid  37921                  Piso barrio de salamanca
#
#      host_id host_name neighbourhood_group   neighbourhood  latitude  \
# 0      13660     Simon           Chamartín  Hispanoamérica  40.45724
# 1      83531     Abdel              Latina        Cármenes  40.40381
# 2  346366726    Alvaro              Centro     Universidad  40.42183
# 3     114340  Agustina          Arganzuela         Legazpi  40.38975
# 4     162926    Sergio           Salamanca       Recoletos  40.42325
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
list_mlg = pd.read_csv(r"Datasets\malaga_listings.csv")
list_mlg.insert(0, "timestamp_date", "2022-12-31")
list_mlg.insert(1, "city", "Málaga")
list_mlg.head()
# Out:
#   timestamp_date    city       id  \
# 0     2022-12-31  Málaga    96033
# 1     2022-12-31  Málaga   166473
# 2     2022-12-31  Málaga  1951589
# 3     2022-12-31  Málaga  4073128
# 4     2022-12-31  Málaga   212845
#
#                                                 name   host_id  host_name  \
# 0  * Cosy flat 200m from the beach, El Palo/Malaga *    510467     Rafael
# 1                         Perfect Location In Malaga    793360       Fred
# 2                Apartment city centre Larios Street  10070230    Rodrigo
# 3                            Grande maison de charme   1856625  Jean-Marc
# 4                    BEAUTIFUL DOUBLE ROOM IN MALAGA    617998      Valle
#
#    neighbourhood_group neighbourhood   latitude  longitude        room_type  \
# 0                  NaN          Este  36.720310  -4.356270  Entire home/apt
# 1                  NaN          Este  36.719340  -4.359420     Private room
# 2                  NaN        Centro  36.721474  -4.420971  Entire home/apt
# ...

# %%
list_mlc = pd.read_csv(r"Datasets\mallorca_listings.csv")
list_mlc.insert(0, "timestamp_date", "2022-12-16")
list_mlc.insert(1, "city", "Mallorca")
list_mlc.head()
# Out:
#   timestamp_date      city      id                               name  \
# 0     2022-12-16  Mallorca   11547               My home at the beach
# 1     2022-12-16  Mallorca   69998  COZY HIDEAWAY  LOFT... MI AMOR...
# 2     2022-12-16  Mallorca  106833  Villa with a big pool in Mallorca
# 3     2022-12-16  Mallorca  159218       Farmhouse in Nature -ET-3025
# 4     2022-12-16  Mallorca  168668      Beautiful farmhouse with pool
#
#    host_id host_name  neighbourhood_group               neighbourhood  \
# 0    42942    Daniel                  NaN                      Calvià
# 1   353156       Lor                  NaN           Palma de Mallorca
# 2   551974     Xisco                  NaN  Sant Llorenç des Cardassar
# 3   763897   Gabriel                  NaN                       Selva
# 4   804061    Miquel                  NaN                     Manacor
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
list_mnc = pd.read_csv(r"Datasets\menorca_listings.csv")
list_mnc.insert(0, "timestamp_date", "2022-12-31")
list_mnc.insert(1, "city", "Menorca")
list_mnc.head()
# Out:
#   timestamp_date     city      id  \
# 0     2022-12-31  Menorca   44085
# 1     2022-12-31  Menorca  285865
# 2     2022-12-31  Menorca  294398
# 3     2022-12-31  Menorca  295705
# 4     2022-12-31  Menorca  334376
#
#                                           name  host_id host_name  \
# 0  Villa in Addaia great sea view and fun pool   193043   Manuela
# 1           Apartment sea view + swimming pool  1487752   Roberto
# 2              Son Esquella - Charming Menorca   312145   Natalia
# 3           The Most Perfect Villa in Menorca!   312145   Natalia
# 4            Nice traditional house in Menorca  1913268   Familia
#
#    neighbourhood_group          neighbourhood  latitude  longitude  \
# 0                  NaN            Es Mercadal  40.00946    4.20026
# 1                  NaN  Ciutadella de Menorca  40.00088    3.79955
# 2                  NaN                 Alaior  39.89089    4.11607
# 3                  NaN                 Alaior  39.89183    4.11577
# ...

# %%
list_sev = pd.read_csv(r"Datasets\sevilla_listings.csv")
list_sev.insert(0, "timestamp_date", "2022-12-30")
list_sev.insert(1, "city", "Sevilla")
list_sev.head()
# Out:
#   timestamp_date     city      id  \
# 0     2022-12-30  Sevilla   32347
# 1     2022-12-30  Sevilla   49287
# 2     2022-12-30  Sevilla  898135
# 3     2022-12-30  Sevilla  108236
# 4     2022-12-30  Sevilla  898157
#
#                                                 name  host_id  \
# 0  Explore Cultural Sights from a Family-Friendly...   139939
# 1                     BEAUTIFUL APARTMENT IN SEVILLE   224697
# 2                                    Ático Laraña IV  4790497
# 3                    Sunny apt in heart of seville!!   560040
# 4                                     Laraña Mirador  4790497
#
#                             host_name neighbourhood_group neighbourhood  \
# 0                           Alejandro       Casco Antiguo   San Vicente
# 1                              Walter       Casco Antiguo   San Lorenzo
# 2  Apartamentos Diaber - Book Seville       Casco Antiguo       Alfalfa
# 3                                Pepe       Casco Antiguo   San Lorenzo
# ...

# %%
list_vlc = pd.read_csv(r"Datasets\valencia_listings.csv")
list_vlc.insert(0, "timestamp_date", "2022-12-21")
list_vlc.insert(1, "city", "Valencia")
list_vlc.head()
# Out:
#   timestamp_date      city      id  \
# 0     2022-12-21  Valencia   55692
# 1     2022-12-21  Valencia   95393
# 2     2022-12-21  Valencia  100347
# 3     2022-12-21  Valencia  136378
# 4     2022-12-21  Valencia  103386
#
#                                                 name  host_id host_name  \
# 0                             Delight in city center   120649     Pilar
# 1   Modern and bright Duplex 3 Bedrooms Center Wi-Fi   508042    Carmen
# 2  3BDR full Home at Sorolla station and Metro Jesús  1451371  Santiago
# 3                 Old City Charm with Modern Comfort   591197     Elisa
# 4                Central 2 Bedrooms, 3/5 pers. Wi-Fi   508042    Carmen
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0        CIUTAT VELLA        LA SEU  39.47658   -0.37654  Entire home/apt
# 1        CIUTAT VELLA      EL CARME  39.47685   -0.38181  Entire home/apt
# 2           EXTRAMURS   ARRANCAPINS  39.45965   -0.38453  Entire home/apt
# ...

# %% [markdown]
# #### Importar todos los archivos de listings (parte 2)

# %%
list_bcn2 = pd.read_csv(r'Datasets\barcelona_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_bcn2.insert(0, "timestamp_date", "2022-12-11")
list_bcn2.insert(1, "city", "Barcelona")
list_bcn2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\960231494.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_bcn2 = pd.read_csv(r'Datasets\barcelona_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date       city      id                          listing_url  \
# 0     2022-12-11  Barcelona   18674   https://www.airbnb.com/rooms/18674
# 1     2022-12-11  Barcelona  124342  https://www.airbnb.com/rooms/124342
# 2     2022-12-11  Barcelona  128463  https://www.airbnb.com/rooms/128463
# 3     2022-12-11  Barcelona  130227  https://www.airbnb.com/rooms/130227
# 4     2022-12-11  Barcelona  135513  https://www.airbnb.com/rooms/135513
#
#         scrape_id last_scraped       source  \
# 0  20221211170659   2022-12-11  city scrape
# 1  20221211170659   2022-12-11  city scrape
# 2  20221211170659   2022-12-12  city scrape
# 3  20221211170659   2022-12-11  city scrape
# ...

# %%
list_eus2 = pd.read_csv(r'Datasets\euskadi_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_eus2.insert(0, "timestamp_date", "2022-12-30")
list_eus2.insert(1, "city", "Euskadi")
list_eus2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\145897294.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_eus2 = pd.read_csv(r'Datasets\euskadi_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city       id                           listing_url  \
# 0     2022-12-30  Euskadi   132068   https://www.airbnb.com/rooms/132068
# 1     2022-12-30  Euskadi   142760   https://www.airbnb.com/rooms/142760
# 2     2022-12-30  Euskadi   309802   https://www.airbnb.com/rooms/309802
# 3     2022-12-30  Euskadi  2718467  https://www.airbnb.com/rooms/2718467
# 4     2022-12-30  Euskadi  2725506  https://www.airbnb.com/rooms/2725506
#
#         scrape_id last_scraped       source  \
# 0  20221230232025   2022-12-31  city scrape
# 1  20221230232025   2022-12-31  city scrape
# 2  20221230232025   2022-12-31  city scrape
# 3  20221230232025   2022-12-31  city scrape
# ...

# %%
list_gir2 = pd.read_csv(r'Datasets\girona_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_gir2.insert(0, "timestamp_date", "2022-12-30")
list_gir2.insert(1, "city", "Girona")
list_gir2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2359197037.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_gir2 = pd.read_csv(r'Datasets\girona_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city      id                          listing_url  \
# 0     2022-12-30  Girona   14551   https://www.airbnb.com/rooms/14551
# 1     2022-12-30  Girona   41342   https://www.airbnb.com/rooms/41342
# 2     2022-12-30  Girona   45400   https://www.airbnb.com/rooms/45400
# 3     2022-12-30  Girona   48764   https://www.airbnb.com/rooms/48764
# 4     2022-12-30  Girona  751638  https://www.airbnb.com/rooms/751638
#
#         scrape_id last_scraped           source  \
# 0  20221230232038   2022-12-31      city scrape
# 1  20221230232038   2022-12-31  previous scrape
# 2  20221230232038   2022-12-31      city scrape
# 3  20221230232038   2022-12-31      city scrape
# ...

# %%
list_mad2 = pd.read_csv(r'Datasets\madrid_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_mad2.insert(0, "timestamp_date", "2022-12-13")
list_mad2.insert(1, "city", "Madrid")
list_mad2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\1006661538.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_mad2 = pd.read_csv(r'Datasets\madrid_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city     id                         listing_url  \
# 0     2022-12-13  Madrid   6369   https://www.airbnb.com/rooms/6369
# 1     2022-12-13  Madrid  21853  https://www.airbnb.com/rooms/21853
# 2     2022-12-13  Madrid  24805  https://www.airbnb.com/rooms/24805
# 3     2022-12-13  Madrid  30959  https://www.airbnb.com/rooms/30959
# 4     2022-12-13  Madrid  37921  https://www.airbnb.com/rooms/37921
#
#         scrape_id last_scraped           source  \
# 0  20221213034110   2022-12-13      city scrape
# 1  20221213034110   2022-12-13      city scrape
# 2  20221213034110   2022-12-13      city scrape
# 3  20221213034110   2022-12-13  previous scrape
# ...

# %%
list_mlg2 = pd.read_csv(r'Datasets\malaga_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_mlg2.insert(0, "timestamp_date", "2022-12-31")
list_mlg2.insert(1, "city", "Málaga")
list_mlg2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3662424941.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_mlg2 = pd.read_csv(r'Datasets\malaga_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city       id                           listing_url  \
# 0     2022-12-31  Málaga    96033    https://www.airbnb.com/rooms/96033
# 1     2022-12-31  Málaga   166473   https://www.airbnb.com/rooms/166473
# 2     2022-12-31  Málaga   212845   https://www.airbnb.com/rooms/212845
# 3     2022-12-31  Málaga   330760   https://www.airbnb.com/rooms/330760
# 4     2022-12-31  Málaga  1951589  https://www.airbnb.com/rooms/1951589
#
#         scrape_id last_scraped       source  \
# 0  20221231065740   2022-12-31  city scrape
# 1  20221231065740   2022-12-31  city scrape
# 2  20221231065740   2022-12-31  city scrape
# 3  20221231065740   2022-12-31  city scrape
# ...

# %%
list_mlc2 = pd.read_csv(r'Datasets\mallorca_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_mlc2.insert(0, "timestamp_date", "2022-12-16")
list_mlc2.insert(1, "city", "Mallorca")
list_mlc2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2119708403.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_mlc2 = pd.read_csv(r'Datasets\mallorca_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date      city      id                          listing_url  \
# 0     2022-12-16  Mallorca   11547   https://www.airbnb.com/rooms/11547
# 1     2022-12-16  Mallorca   69998   https://www.airbnb.com/rooms/69998
# 2     2022-12-16  Mallorca  106833  https://www.airbnb.com/rooms/106833
# 3     2022-12-16  Mallorca  159218  https://www.airbnb.com/rooms/159218
# 4     2022-12-16  Mallorca  166820  https://www.airbnb.com/rooms/166820
#
#         scrape_id last_scraped       source  \
# 0  20221216161305   2022-12-17  city scrape
# 1  20221216161305   2022-12-17  city scrape
# 2  20221216161305   2022-12-16  city scrape
# 3  20221216161305   2022-12-16  city scrape
# ...

# %%
list_mnc2 = pd.read_csv(r'Datasets\menorca_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_mnc2.insert(0, "timestamp_date", "2022-12-31")
list_mnc2.insert(1, "city", "Menorca")
list_mnc2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\568531726.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_mnc2 = pd.read_csv(r'Datasets\menorca_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city      id                          listing_url  \
# 0     2022-12-31  Menorca   44085   https://www.airbnb.com/rooms/44085
# 1     2022-12-31  Menorca  285865  https://www.airbnb.com/rooms/285865
# 2     2022-12-31  Menorca  294398  https://www.airbnb.com/rooms/294398
# 3     2022-12-31  Menorca  295705  https://www.airbnb.com/rooms/295705
# 4     2022-12-31  Menorca  334376  https://www.airbnb.com/rooms/334376
#
#         scrape_id last_scraped       source  \
# 0  20221231065712   2022-12-31  city scrape
# 1  20221231065712   2022-12-31  city scrape
# 2  20221231065712   2022-12-31  city scrape
# 3  20221231065712   2022-12-31  city scrape
# ...

# %%
list_sev2 = pd.read_csv(r'Datasets\sevilla_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_sev2.insert(0, "timestamp_date", "2022-12-30")
list_sev2.insert(1, "city", "Sevilla")
list_sev2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2826888588.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_sev2 = pd.read_csv(r'Datasets\sevilla_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city      id                          listing_url  \
# 0     2022-12-30  Sevilla   32347   https://www.airbnb.com/rooms/32347
# 1     2022-12-30  Sevilla   49287   https://www.airbnb.com/rooms/49287
# 2     2022-12-30  Sevilla  108236  https://www.airbnb.com/rooms/108236
# 3     2022-12-30  Sevilla  108568  https://www.airbnb.com/rooms/108568
# 4     2022-12-30  Sevilla  116703  https://www.airbnb.com/rooms/116703
#
#         scrape_id last_scraped           source  \
# 0  20221230163540   2022-12-31  previous scrape
# 1  20221230163540   2022-12-30      city scrape
# 2  20221230163540   2022-12-31      city scrape
# ...

# %%
list_vlc2 = pd.read_csv(r'Datasets\valencia_listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
list_vlc2.insert(0, "timestamp_date", "2022-12-21")
list_vlc2.insert(1, "city", "Valencia")
list_vlc2.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3789830784.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   list_vlc2 = pd.read_csv(r'Datasets\valencia_listings.csv.gz', nrows=100, compression='gzip',
#   timestamp_date      city      id                          listing_url  \
# 0     2022-12-21  Valencia   55692   https://www.airbnb.com/rooms/55692
# 1     2022-12-21  Valencia   95393   https://www.airbnb.com/rooms/95393
# 2     2022-12-21  Valencia  100347  https://www.airbnb.com/rooms/100347
# 3     2022-12-21  Valencia  102524  https://www.airbnb.com/rooms/102524
# 4     2022-12-21  Valencia  103386  https://www.airbnb.com/rooms/103386
#
#         scrape_id last_scraped           source  \
# 0  20221221170335   2022-12-22  previous scrape
# 1  20221221170335   2022-12-21      city scrape
# 2  20221221170335   2022-12-22  previous scrape
# ...

# %% [markdown]
# #### Importar todos los archivos de calendarios

# %%
cal_bcn = pd.read_csv(r'Datasets\barcelona_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_bcn.insert(0, "timestamp_date", "2022-12-11")
cal_bcn.insert(1, "city", "Barcelona")
cal_bcn.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3600159876.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_bcn = pd.read_csv(r'Datasets\barcelona_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date       city  listing_id        date available    price  \
# 0     2022-12-11  Barcelona       18674  2022-12-11         f  $111.00
# 1     2022-12-11  Barcelona       18674  2022-12-12         f  $111.00
# 2     2022-12-11  Barcelona       18674  2022-12-13         t  $175.00
# 3     2022-12-11  Barcelona       18674  2022-12-14         f  $111.00
# 4     2022-12-11  Barcelona       18674  2022-12-15         f  $111.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0        $111.00               2            1125
# 1        $111.00               2            1125
# 2        $175.00               1            1125
# ...

# %%
cal_eus = pd.read_csv(r'Datasets\euskadi_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_eus.insert(0, "timestamp_date", "2022-12-30")
cal_eus.insert(1, "city", "Euskadi")
cal_eus.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3518784290.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_eus = pd.read_csv(r'Datasets\euskadi_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city  listing_id        date available    price  \
# 0     2022-12-30  Euskadi      132068  2022-12-31         f  $250.00
# 1     2022-12-30  Euskadi      132068  2023-01-01         f  $195.00
# 2     2022-12-30  Euskadi      132068  2023-01-02         f  $160.00
# 3     2022-12-30  Euskadi      132068  2023-01-03         f  $160.00
# 4     2022-12-30  Euskadi      132068  2023-01-04         f  $160.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0        $250.00               1              63
# 1        $195.00               1              63
# 2        $160.00               1              63
# 3        $160.00               1              63
# ...

# %%
cal_gir = pd.read_csv(r'Datasets\girona_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_gir.insert(0, "timestamp_date", "2022-12-30")
cal_gir.insert(1, "city", "Girona")
cal_gir.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2238737303.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_gir = pd.read_csv(r'Datasets\girona_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city  listing_id        date available   price  \
# 0     2022-12-30  Girona       14551  2022-12-31         f  $60.00
# 1     2022-12-30  Girona       14551  2023-01-01         t  $60.00
# 2     2022-12-30  Girona       14551  2023-01-02         t  $60.00
# 3     2022-12-30  Girona       14551  2023-01-03         t  $60.00
# 4     2022-12-30  Girona       14551  2023-01-04         t  $60.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0         $60.00               1            1125
# 1         $60.00               1            1125
# 2         $60.00               1            1125
# 3         $60.00               1            1125
# ...

# %%
cal_mad = pd.read_csv(r'Datasets\malaga_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_mad.insert(0, "timestamp_date", "2022-12-13")
cal_mad.insert(1, "city", "Madrid")
cal_mad.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\4219869611.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_mad = pd.read_csv(r'Datasets\malaga_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city  listing_id        date available   price  \
# 0     2022-12-13  Madrid       96033  2022-12-31         f  $48.00
# 1     2022-12-13  Madrid       96033  2023-01-01         f  $49.00
# 2     2022-12-13  Madrid       96033  2023-01-02         f  $49.00
# 3     2022-12-13  Madrid       96033  2023-01-03         f  $49.00
# 4     2022-12-13  Madrid       96033  2023-01-04         f  $49.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0         $48.00               5            1125
# 1         $49.00               5            1125
# 2         $49.00               5            1125
# 3         $49.00               5            1125
# ...

# %%
cal_mlg = pd.read_csv(r'Datasets\malaga_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_mlg.insert(0, "timestamp_date", "2022-12-31")
cal_mlg.insert(1, "city", "Málaga")
cal_mlg.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3922996604.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_mlg = pd.read_csv(r'Datasets\malaga_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city  listing_id        date available   price  \
# 0     2022-12-31  Málaga       96033  2022-12-31         f  $48.00
# 1     2022-12-31  Málaga       96033  2023-01-01         f  $49.00
# 2     2022-12-31  Málaga       96033  2023-01-02         f  $49.00
# 3     2022-12-31  Málaga       96033  2023-01-03         f  $49.00
# 4     2022-12-31  Málaga       96033  2023-01-04         f  $49.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0         $48.00               5            1125
# 1         $49.00               5            1125
# 2         $49.00               5            1125
# 3         $49.00               5            1125
# ...

# %%
cal_mlc = pd.read_csv(r'Datasets\mallorca_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_mlc.insert(0, "timestamp_date", "2022-12-16")
cal_mlc.insert(1, "city", "Mallorca")
cal_mlc.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3724902967.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_mlc = pd.read_csv(r'Datasets\mallorca_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date      city  listing_id        date available    price  \
# 0     2022-12-16  Mallorca       11547  2022-12-17         f  $125.00
# 1     2022-12-16  Mallorca       11547  2022-12-18         t  $125.00
# 2     2022-12-16  Mallorca       11547  2022-12-19         t  $125.00
# 3     2022-12-16  Mallorca       11547  2022-12-20         t  $125.00
# 4     2022-12-16  Mallorca       11547  2022-12-21         t  $125.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0        $125.00               7            1125
# 1        $125.00               7            1125
# 2        $125.00               7            1125
# 3        $125.00               7            1125
# ...

# %%
cal_mnc = pd.read_csv(r'Datasets\menorca_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_mnc.insert(0, "timestamp_date", "2022-12-31")
cal_mnc.insert(1, "city", "Menorca")
cal_mnc.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\216333459.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_mnc = pd.read_csv(r'Datasets\menorca_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city  listing_id        date available   price  \
# 0     2022-12-31  Menorca       44085  2022-12-31         f  $63.00
# 1     2022-12-31  Menorca       44085  2023-01-01         f  $63.00
# 2     2022-12-31  Menorca       44085  2023-01-02         f  $63.00
# 3     2022-12-31  Menorca       44085  2023-01-03         f  $63.00
# 4     2022-12-31  Menorca       44085  2023-01-04         f  $63.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0         $57.00               5            1125
# 1         $57.00               5            1125
# 2         $57.00               5            1125
# 3         $57.00               5            1125
# ...

# %%
cal_sev = pd.read_csv(r'Datasets\sevilla_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_sev.insert(0, "timestamp_date", "2022-12-30")
cal_sev.insert(1, "city", "Sevilla")
cal_sev.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3465975363.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_sev = pd.read_csv(r'Datasets\sevilla_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city  listing_id        date available   price  \
# 0     2022-12-30  Sevilla       32347  2022-12-31         f  $99.00
# 1     2022-12-30  Sevilla       32347  2023-01-01         f  $99.00
# 2     2022-12-30  Sevilla       32347  2023-01-02         f  $99.00
# 3     2022-12-30  Sevilla       32347  2023-01-03         f  $99.00
# 4     2022-12-30  Sevilla       32347  2023-01-04         f  $99.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0         $99.00               2            1125
# 1         $99.00               2            1125
# 2         $99.00               2            1125
# 3         $99.00               2            1125
# ...

# %%
cal_vlc = pd.read_csv(r'Datasets\valencia_calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
cal_vlc.insert(0, "timestamp_date", "2022-12-21")
cal_vlc.insert(1, "city", "Valencia")
cal_vlc.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\4152077711.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cal_vlc = pd.read_csv(r'Datasets\valencia_calendar.csv.gz', nrows=100, compression='gzip',
#   timestamp_date      city  listing_id        date available    price  \
# 0     2022-12-21  Valencia       55692  2022-12-22         f  $100.00
# 1     2022-12-21  Valencia       55692  2022-12-23         f  $100.00
# 2     2022-12-21  Valencia       55692  2022-12-24         f  $100.00
# 3     2022-12-21  Valencia       55692  2022-12-25         f  $100.00
# 4     2022-12-21  Valencia       55692  2022-12-26         f  $100.00
#
#   adjusted_price  minimum_nights  maximum_nights
# 0        $100.00               1             730
# 1        $100.00               1             730
# 2        $100.00               1             730
# 3        $100.00               1             730
# ...

# %% [markdown]
# #### Importar todos los archivos de reseñas

# %%
rev_bcn = pd.read_csv(r'Datasets\barcelona_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_bcn.insert(0, "timestamp_date", "2022-12-11")
rev_bcn.insert(1, "city", "Barcelona")
rev_bcn.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\422968077.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_bcn = pd.read_csv(r'Datasets\barcelona_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date       city  listing_id         id        date  reviewer_id  \
# 0     2022-12-11  Barcelona       18674    4808211  2013-05-27      4841196
# 1     2022-12-11  Barcelona       18674   10660311  2014-03-02     11600277
# 2     2022-12-11  Barcelona       18674   41087522  2015-08-04     35231385
# 3     2022-12-11  Barcelona       18674   81000756  2016-06-20     23223644
# 4     2022-12-11  Barcelona       18674  278588962  2018-06-18      4756672
#
#   reviewer_name                                           comments
# 0         Caron  Great location. Clean, spacious flat. Would re...
# 1   Juan Carlos  Mi mejor recomendación para este departamento....
# ...

# %%
rev_eus = pd.read_csv(r'Datasets\euskadi_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_eus.insert(0, "timestamp_date", "2022-12-30")
rev_eus.insert(1, "city", "Euskadi")
rev_eus.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3038872576.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_eus = pd.read_csv(r'Datasets\euskadi_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city  listing_id        id        date  reviewer_id  \
# 0     2022-12-30  Euskadi      132068    297597  2011-06-04       182987
# 1     2022-12-30  Euskadi      132068  12519461  2014-05-04      5175212
# 2     2022-12-30  Euskadi      132068  12600130  2014-05-05      2789268
# 3     2022-12-30  Euskadi      132068  13253988  2014-05-23       298828
# 4     2022-12-30  Euskadi      132068  13294951  2014-05-24      7736822
#
#            reviewer_name                                           comments
# 0                  Irina  Mikel's place was outrageous, a perfect combin...
# 1  Philippine & Grégoire  Mikel appartment is exactly as it is described...
# ...

# %%
rev_gir = pd.read_csv(r'Datasets\girona_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_gir.insert(0, "timestamp_date", "2022-12-30")
rev_gir.insert(1, "city", "Girona")
rev_gir.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3022458444.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_gir = pd.read_csv(r'Datasets\girona_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city  listing_id       id        date  reviewer_id  \
# 0     2022-12-30  Girona       14551   113976  2010-10-08       163608
# 1     2022-12-30  Girona       14551  4011836  2013-04-02      2127547
# 2     2022-12-30  Girona       14551  5626230  2013-07-08      7232706
# 3     2022-12-30  Girona       14551  6162226  2013-08-01      7296648
# 4     2022-12-30  Girona       14551  6358591  2013-08-09      7576760
#
#   reviewer_name                                           comments
# 0        Sharon  Mun is a delightful host, and went out of her ...
# 1       Antoine  We had a lovely stay at Mun's! She is a very w...
# ...

# %%
rev_mad = pd.read_csv(r'Datasets\madrid_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_mad.insert(0, "timestamp_date", "2022-12-13")
rev_mad.insert(1, "city", "Madrid")
rev_mad.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\3700313940.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_mad = pd.read_csv(r'Datasets\madrid_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city  listing_id     id        date  reviewer_id  \
# 0     2022-12-13  Madrid        6369  29428  2010-03-14        84790
# 1     2022-12-13  Madrid        6369  31018  2010-03-23        84338
# 2     2022-12-13  Madrid        6369  34694  2010-04-10        98655
# 3     2022-12-13  Madrid        6369  37146  2010-04-21       109871
# 4     2022-12-13  Madrid        6369  38168  2010-04-26        98901
#
#   reviewer_name                                           comments
# 0         Nancy  Simon and Arturo have the ultimate location in...
# 1         David  Myself and Kristy originally planned on stayin...
# ...

# %%
rev_mlg = pd.read_csv(r'Datasets\malaga_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_mlg.insert(0, "timestamp_date", "2022-12-31")
rev_mlg.insert(1, "city", "Málaga")
rev_mlg.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2566550377.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_mlg = pd.read_csv(r'Datasets\malaga_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date    city  listing_id        id        date  reviewer_id  \
# 0     2022-12-31  Málaga       96033   8152056  2013-10-18       366364
# 1     2022-12-31  Málaga       96033   8689156  2013-11-12      4862098
# 2     2022-12-31  Málaga       96033  11275860  2014-03-27     12189558
# 3     2022-12-31  Málaga       96033  11862773  2014-04-17      2236416
# 4     2022-12-31  Málaga       96033  12689717  2014-05-08     13440727
#
#   reviewer_name                                           comments
# 0          Vera  My stay at the apartment of Adriana and Rafa w...
# 1         Sarah  The flat was perfect for our holiday in Malaga...
# ...

# %%
rev_mlc = pd.read_csv(r'Datasets\mallorca_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_mlc.insert(0, "timestamp_date", "2022-12-16")
rev_mlc.insert(1, "city", "Mallorca")
rev_mlc.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2401233751.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_mlc = pd.read_csv(r'Datasets\mallorca_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date      city  listing_id       id        date  reviewer_id  \
# 0     2022-12-16  Mallorca       69998   881474  2012-01-24      1595616
# 1     2022-12-16  Mallorca       69998  4007103  2013-04-02      3868130
# 2     2022-12-16  Mallorca       69998  4170371  2013-04-15      5730759
# 3     2022-12-16  Mallorca       11547   469543  2011-08-23       864304
# 4     2022-12-16  Mallorca       11547  2169130  2012-09-02      2661942
#
#   reviewer_name                                           comments
# 0   Jean-Pierre  This place was charming! Lorenzo himself is a ...
# 1   Jo And Mike  We had a four night stay at this gorgeous apar...
# ...

# %%
rev_mnc = pd.read_csv(r'Datasets\menorca_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_mnc.insert(0, "timestamp_date", "2022-12-31")
rev_mnc.insert(1, "city", "Menorca")
rev_mnc.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\774128527.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_mnc = pd.read_csv(r'Datasets\menorca_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city  listing_id        id        date  reviewer_id  \
# 0     2022-12-31  Menorca       44085   1639831  2012-07-06      1148512
# 1     2022-12-31  Menorca       44085   4750726  2013-05-23      4180108
# 2     2022-12-31  Menorca       44085   5739873  2013-07-14      7168741
# 3     2022-12-31  Menorca       44085  34596379  2015-06-09      6636779
# 4     2022-12-31  Menorca       44085  46858585  2015-09-14     26646324
#
#   reviewer_name                                           comments
# 0       Beatriz  Casa Binimasr es perfecta para unas vacaciones...
# 1      Fabrizio  The house was simply stunning! In a very quiet...
# ...

# %%
rev_sev = pd.read_csv(r'Datasets\sevilla_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_sev.insert(0, "timestamp_date", "2022-12-30")
rev_sev.insert(1, "city", "Sevilla")
rev_sev.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2868874939.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_sev = pd.read_csv(r'Datasets\sevilla_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date     city  listing_id       id        date  reviewer_id  \
# 0     2022-12-30  Sevilla       32347   166105  2011-01-05       177444
# 1     2022-12-30  Sevilla       32347   238321  2011-04-25       356558
# 2     2022-12-30  Sevilla       32347   508902  2011-09-06       723051
# 3     2022-12-30  Sevilla       32347  1056439  2012-03-28       873621
# 4     2022-12-30  Sevilla       32347  1102628  2012-04-09      1853585
#
#   reviewer_name                                           comments
# 0         Peter                     Great location and great host!
# 1      Nicholas                excellent apartment, great location
# ...

# %%
rev_vlc = pd.read_csv(r'Datasets\valencia_reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
rev_vlc.insert(0, "timestamp_date", "2022-12-21")
rev_vlc.insert(1, "city", "Valencia")
rev_vlc.head()
# Out:
# C:\Users\Selvie\AppData\Local\Temp\ipykernel_16336\2231590972.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rev_vlc = pd.read_csv(r'Datasets\valencia_reviews.csv.gz', nrows=100, compression='gzip',
#   timestamp_date      city  listing_id        id        date  reviewer_id  \
# 0     2022-12-21  Valencia       55692  22677486  2014-11-11     15475069
# 1     2022-12-21  Valencia       95393    313822  2011-06-14       341678
# 2     2022-12-21  Valencia       95393    763753  2011-12-05      1249565
# 3     2022-12-21  Valencia       95393   1166561  2012-04-23      1647125
# 4     2022-12-21  Valencia       95393   2148805  2012-08-31      2397271
#
#   reviewer_name                                           comments
# 0      Federico  Somos estado muy bien El apartamento es muy gu...
# 1        Nicole  We stayed for 5 days at Palomar. In an apartme...
# ...

# %% [markdown]
# #### Juntar todos los archivos de ciudades

# %% [markdown]
# ##### Lista de propiedades - España

# %%
list_es = pd.concat((list_bcn, list_eus, list_gir, list_mad, list_mlg, list_mlc, list_mnc, list_sev, list_vlc), axis=0)
list_es.head()
# Out:
#   timestamp_date       city     id  \
# 0     2022-12-11  Barcelona  18674
# 1     2022-12-11  Barcelona  23197
# 2     2022-12-11  Barcelona  32711
# 3     2022-12-11  Barcelona  34981
# 4     2022-12-11  Barcelona  36763
#
#                                               name  host_id         host_name  \
# 0  Huge flat for 8 people close to Sagrada Familia    71615  Mireia And Maria
# 1  Forum CCIB DeLuxe, Spacious, Elegant ,Christmas    90417    Etain (Marnie)
# 2                 Sagrada Familia area - Còrsega 1   135703              Nick
# 3             VIDRE HOME PLAZA REAL on LAS RAMBLAS    73163            Andres
# 4                            In front of the beach   158596             Ester
#
#   neighbourhood_group                       neighbourhood  latitude  \
# 0            Eixample                  la Sagrada Família  41.40556
# 1          Sant Martí               el Besòs i el Maresme  41.41243
# 2              Gràcia  el Camp d'en Grassot i Gràcia Nova  41.40566
# ...

# %%
list_es.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102881 entries, 0 to 6710
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   timestamp_date                  102881 non-null  object
#  1   city                            102881 non-null  object
#  2   id                              102881 non-null  int64
#  3   name                            102857 non-null  object
#  4   host_id                         102881 non-null  int64
#  5   host_name                       102817 non-null  object
#  6   neighbourhood_group             55889 non-null   object
#  7   neighbourhood                   102881 non-null  object
#  8   latitude                        102881 non-null  float64
#  9   longitude                       102881 non-null  float64
#  10  room_type                       102881 non-null  object
#  11  price                           102881 non-null  int64
# ...

# %%
# Remove the neighbourhood columns because we will get the complete address from Geopy Nominatim API

list_es = list_es.drop(["neighbourhood_group", "neighbourhood"], axis=1)
list_es
# Out:
#      timestamp_date       city                  id  \
# 0        2022-12-11  Barcelona               18674
# 1        2022-12-11  Barcelona               23197
# 2        2022-12-11  Barcelona               32711
# 3        2022-12-11  Barcelona               34981
# 4        2022-12-11  Barcelona               36763
# ...             ...        ...                 ...
# 6706     2022-12-21   Valencia  785689203850632931
# 6707     2022-12-21   Valencia  785971133185009634
# 6708     2022-12-21   Valencia  786120918642825480
# 6709     2022-12-21   Valencia  786125428040961074
# 6710     2022-12-21   Valencia  786165037887203536
#
#                                                  name    host_id  \
# 0     Huge flat for 8 people close to Sagrada Familia      71615
# 1     Forum CCIB DeLuxe, Spacious, Elegant ,Christmas      90417
# 2                    Sagrada Familia area - Còrsega 1     135703
# 3                VIDRE HOME PLAZA REAL on LAS RAMBLAS      73163
# ...

# %%
list_es.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102881 entries, 0 to 6710
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   timestamp_date                  102881 non-null  object
#  1   city                            102881 non-null  object
#  2   id                              102881 non-null  int64
#  3   name                            102857 non-null  object
#  4   host_id                         102881 non-null  int64
#  5   host_name                       102817 non-null  object
#  6   latitude                        102881 non-null  float64
#  7   longitude                       102881 non-null  float64
#  8   room_type                       102881 non-null  object
#  9   price                           102881 non-null  int64
#  10  minimum_nights                  102881 non-null  int64
#  11  number_of_reviews               102881 non-null  int64
# ...

# %%
list_es["room_type"].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
list_es.to_csv("Datasets_clean/listing_es.csv")

# %% [markdown]
# ##### Lista de propiedades (parte 2) - España

# %%
list_es2 = pd.concat((list_bcn2, list_eus2, list_gir2, list_mad2, list_mlg2, list_mlc2, list_mnc2, list_sev2, list_vlc2), axis=0)
list_es2.head()
# Out:
#   timestamp_date       city      id                          listing_url  \
# 0     2022-12-11  Barcelona   18674   https://www.airbnb.com/rooms/18674
# 1     2022-12-11  Barcelona  124342  https://www.airbnb.com/rooms/124342
# 2     2022-12-11  Barcelona  128463  https://www.airbnb.com/rooms/128463
# 3     2022-12-11  Barcelona  130227  https://www.airbnb.com/rooms/130227
# 4     2022-12-11  Barcelona  135513  https://www.airbnb.com/rooms/135513
#
#         scrape_id last_scraped       source  \
# 0  20221211170659   2022-12-11  city scrape
# 1  20221211170659   2022-12-11  city scrape
# 2  20221211170659   2022-12-12  city scrape
# 3  20221211170659   2022-12-11  city scrape
# 4  20221211170659   2022-12-11  city scrape
#
#                                               name  \
# 0  Huge flat for 8 people close to Sagrada Familia
# 1  BORN CENTRICO / MUSEO PICASSO / 10 min to BEACH
# 2              Private Suite in residential area!!
# ...

# %%
list_es2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 99
# Data columns (total 77 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   timestamp_date                                900 non-null    object
#  1   city                                          900 non-null    object
#  2   id                                            900 non-null    int64
#  3   listing_url                                   900 non-null    object
#  4   scrape_id                                     900 non-null    int64
#  5   last_scraped                                  900 non-null    object
#  6   source                                        900 non-null    object
#  7   name                                          900 non-null    object
#  8   description                                   900 non-null    object
# ...

# %%
list_es2.columns
# Out:
# Index(['timestamp_date', 'city', 'id', 'listing_url', 'scrape_id',
#        'last_scraped', 'source', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
# ...

# %%
# Remove the neighbourhood columns because we will get the complete address from Geopy Nominatim API

list_es2 = list_es2.drop(["neighbourhood", "neighbourhood_cleansed", "neighbourhood_group_cleansed"], axis=1)
list_es2
# Out:
#    timestamp_date       city       id                           listing_url  \
# 0      2022-12-11  Barcelona    18674    https://www.airbnb.com/rooms/18674
# 1      2022-12-11  Barcelona   124342   https://www.airbnb.com/rooms/124342
# 2      2022-12-11  Barcelona   128463   https://www.airbnb.com/rooms/128463
# 3      2022-12-11  Barcelona   130227   https://www.airbnb.com/rooms/130227
# 4      2022-12-11  Barcelona   135513   https://www.airbnb.com/rooms/135513
# ..            ...        ...      ...                                   ...
# 95     2022-12-21   Valencia  3675253  https://www.airbnb.com/rooms/3675253
# 96     2022-12-21   Valencia  3684986  https://www.airbnb.com/rooms/3684986
# 97     2022-12-21   Valencia  3719698  https://www.airbnb.com/rooms/3719698
# 98     2022-12-21   Valencia  3736295  https://www.airbnb.com/rooms/3736295
# 99     2022-12-21   Valencia  3759310  https://www.airbnb.com/rooms/3759310
#
#          scrape_id last_scraped           source  \
# ...

# %%
list_es2['host_acceptance_rate'].unique()
# Out:
# array(['94%', '43%', '100%', '18%', '87%', '93%', nan, '88%', '42%',
#        '60%', '97%', '75%', '78%', '98%', '50%', '0%', '5%', '96%', '47%',
#        '92%', '99%', '91%', '86%', '80%', '95%', '67%', '83%', '54%',
#        '53%', '61%', '58%', '89%', '81%', '38%', '90%', '85%', '33%',
#        '17%', '68%', '73%', '36%', '19%', '63%', '55%', '76%', '31%',
#        '70%', '48%', '30%', '46%', '72%', '77%', '64%', '79%', '82%',
#        '71%', '41%', '74%', '84%', '25%', '40%', '29%', '69%', '39%',
#        '65%', '57%', '22%', '44%', '52%', '56%', '10%', '24%', '4%',
#        '20%'], dtype=object)

# %%
list_es2['host_since'].unique()
# Out:
# array(['2010-01-19', '2011-05-01', '2011-05-28', '2011-05-30',
#        '2011-06-04', '2010-03-09', '2011-05-21', '2010-05-31',
#        '2012-02-27', '2011-05-08', '2012-03-01', '2011-05-24',
#        '2010-01-24', '2011-06-14', '2010-07-05', '2011-06-17',
#        '2010-07-22', '2010-07-28', '2011-03-31', '2011-02-19',
#        '2010-11-24', '2011-01-09', '2011-10-07', '2011-07-21',
#        '2011-01-28', '2011-08-04', '2011-11-27', '2011-08-10',
#        '2011-01-30', '2011-02-03', '2011-05-27', '2011-08-15',
#        '2011-11-26', '2012-03-12', '2012-02-14', '2011-02-17',
#        '2011-03-14', '2011-08-24', '2011-06-07', '2011-08-29',
#        '2012-10-06', '2011-03-09', '2011-09-04', '2011-04-06',
#        '2012-03-19', '2011-07-26', '2011-09-29', '2012-03-23',
#        '2012-03-30', '2011-04-28', '2011-10-06', '2012-04-05',
#        '2012-04-10', '2011-09-20', '2012-04-11', '2019-09-25',
#        '2011-10-19', '2011-07-31', '2012-03-25', '2012-04-19',
# ...

# %%
list_es2['reviews_per_month'].unique()
# Out:
# array([0.28, 0.56, 2.53, 1.24, 0.96, 0.45, 0.95, 0.6 , 3.06, 0.79, 0.21,
#        0.2 , 1.28, 0.27, 0.76, 1.37, 1.82, 0.47, 0.68, 0.03, 0.44, 0.49,
#        2.57, 0.24, 0.66, 0.9 , 0.5 , 0.01, 0.73, 0.51, 0.17, 2.44, 0.08,
#        0.83, 5.95, 0.02, 0.06, 2.64, 1.18, 0.65, 0.69, 0.93, 3.88, 2.59,
#        0.38, 0.07, 1.23, 0.57, 1.49, 0.89, 1.15, 2.56, 1.95, 1.09, 0.78,
#        1.21, 0.18, 2.77, 0.36, 0.88, 0.61, 3.47, 0.8 , 1.69, 0.4 , 0.87,
#        0.19, 0.04, 0.13, 2.14, 2.49, 1.83, 0.31, 2.5 , 0.99, 3.51, 2.45,
#        1.71, 4.57, 1.42, 0.48, 4.68, 1.36, 2.12, 0.09, 0.16, 0.35, 1.22,
#        1.26, 0.52, 0.7 , 1.  , 1.05, 3.98, 1.25, 0.92, 4.6 , 1.08, 0.11,
#        2.09, 1.53, 1.62, 0.42, 0.53, 0.74, 1.35, 0.34, 2.84, 0.23, 0.75,
#        1.33, 0.1 , 1.04, 2.27, 0.12,  nan, 0.77, 1.91, 1.13, 0.05, 0.43,
#        7.14, 1.39, 5.29, 2.86, 6.51, 0.29, 3.53, 2.32, 0.39, 0.3 , 8.11,
#        0.37, 2.51, 0.33, 0.63, 0.32, 0.15, 0.26, 2.65, 1.96, 0.81, 0.41,
# ...

# %%
list_es2['host_response_time'].unique()
# Out:
# array(['within an hour', 'within a day', nan, 'within a few hours',
#        'a few days or more'], dtype=object)

# %%
list_es2['host_response_rate'].unique()
# Out:
# array(['100%', '60%', nan, '83%', '50%', '93%', '96%', '0%', '54%', '82%',
#        '99%', '87%', '90%', '64%', '97%', '75%', '95%', '17%', '67%',
#        '89%', '10%', '62%', '70%', '80%', '20%', '91%', '13%', '78%',
#        '86%', '88%', '59%', '71%', '94%', '92%'], dtype=object)

# %%
list_es2['host_acceptance_rate'].unique()
# Out:
# array(['94%', '43%', '100%', '18%', '87%', '93%', nan, '88%', '42%',
#        '60%', '97%', '75%', '78%', '98%', '50%', '0%', '5%', '96%', '47%',
#        '92%', '99%', '91%', '86%', '80%', '95%', '67%', '83%', '54%',
#        '53%', '61%', '58%', '89%', '81%', '38%', '90%', '85%', '33%',
#        '17%', '68%', '73%', '36%', '19%', '63%', '55%', '76%', '31%',
#        '70%', '48%', '30%', '46%', '72%', '77%', '64%', '79%', '82%',
#        '71%', '41%', '74%', '84%', '25%', '40%', '29%', '69%', '39%',
#        '65%', '57%', '22%', '44%', '52%', '56%', '10%', '24%', '4%',
#        '20%'], dtype=object)

# %%
list_es2['property_type'].unique()
# Out:
# array(['Entire rental unit', 'Private room in rental unit',
#        'Private room in condo', 'Entire loft',
#        'Entire serviced apartment', 'Entire home', 'Entire condo',
#        'Private room in home', 'Room in hotel', 'Entire villa',
#        'Private room in villa', 'Private room in townhouse',
#        'Private room in cottage', 'Entire guesthouse', 'Entire cottage',
#        'Private room in bed and breakfast', 'Private room in hostel',
#        'Entire cabin', 'Private room in loft', 'Farm stay',
#        'Entire townhouse', 'Shared room in rental unit',
#        'Private room in casa particular', 'Private room in guest suite',
#        'Private room in chalet', 'Entire bungalow', 'Castle',
#        'Entire place', 'Room in boutique hotel', 'Camper/RV',
#        'Entire chalet', 'Boat', 'Private room in guesthouse',
#        'Private room in tiny home', 'Tiny home'], dtype=object)

# %%
list_es2['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
list_es2['accommodates'].unique()
# Out:
# array([ 8,  2,  5,  1,  6,  4,  3,  9, 12,  7, 10, 16, 13, 15, 11],
#       dtype=int64)

# %%
list_es2['bathrooms_text'].unique()
# Out:
# array(['2 baths', '1 shared bath', '1 private bath', '1.5 baths',
#        '1 bath', '3 baths', '2 shared baths', '3.5 baths', '4 baths',
#        '2.5 baths', '1.5 shared baths', 'Half-bath', '5 baths',
#        '4.5 baths', '6.5 baths', '6 baths', '7.5 baths', '3 shared baths',
#        '7 baths', nan, 'Shared half-bath', '9 baths', '5.5 baths',
#        '2.5 shared baths', '0 shared baths'], dtype=object)

# %%
list_es2['bedrooms'].unique()
# Out:
# array([ 3.,  1.,  2.,  4., nan,  6.,  8.,  5.,  9.,  7., 11.])

# %%
list_es2['beds'].unique()
# Out:
# array([ 6.,  1.,  3.,  4.,  2.,  7.,  5., 14.,  8., 18.,  9., 12., 11.,
#        17., 21., 15., nan, 10., 13., 16., 20.])

# %%
list_es2['amenities'].unique()
# Out:
# array(['["Essentials", "Crib", "Hair dryer", "Iron", "Host greets you", "Private patio or balcony", "Elevator", "Heating", "Free street parking", "Refrigerator", "30\\" TV", "Hangers", "Dishes and silverware", "Shampoo", "City skyline view", "Kitchen", "Hot water", "Coffee maker", "AC - split type ductless system", "Free washer \\u2013 In unit", "Paid parking on premises", "Wifi", "Long term stays allowed", "Pack \\u2019n play/Travel crib"]',
#        '["Outdoor furniture", "Outdoor dining area", "Washer", "Dedicated workspace", "Oven", "Hair dryer", "Iron", "BBQ grill", "Freezer", "Heating", "Bluetooth sound system", "Refrigerator", "Patio or balcony", "Beach access", "HDTV with Netflix, HBO Max", "Dishes and silverware", "Kitchen", "Hot water", "Coffee maker", "Wifi", "Long term stays allowed", "Cooking basics"]',
# ...

# %%
list_es2['minimum_nights'].unique()
# Out:
# array([  1,   3,  31,  90,   4,  32,   2,   5,  63,   7,  28,   6,  30,
#         60, 120,  20,  14,   8,  10,  15, 365,  64,  29], dtype=int64)

# %%
list_es2['review_scores_rating'].unique()
# Out:
# array([4.31, 4.56, 4.87, 4.72, 4.64, 4.75, 4.59, 4.4 , 4.67, 4.46, 4.2 ,
#        4.35, 4.51, 4.28, 4.79, 4.24, 4.37, 4.38, 4.86, 4.58, 4.68, 4.78,
#        4.41, 4.74, 4.71, 5.  , 4.21, 4.93, 4.  , 4.45, 4.33, 4.52, 4.57,
#        4.1 , 4.12, 4.65, 4.77, 4.22, 3.57, 4.11, 4.69, 4.97, 4.61, 4.36,
#        4.66, 4.8 , 4.63, 4.73, 4.3 , 3.5 , 0.  , 4.23, 4.34, 4.62, 4.5 ,
#        4.85, 4.55, 3.75, 4.29, 4.88, 4.47, 4.96, 4.7 , 4.98, 4.82, 4.44,
#        4.49, 4.27, 4.53, 4.83, 4.89, 4.84,  nan, 4.48, 4.32, 4.6 , 4.94,
#        4.76, 4.91, 4.81, 4.92, 4.54, 4.42, 4.95, 3.  , 3.8 , 4.13, 4.17,
#        4.43, 4.19, 4.39, 4.16, 4.26, 4.9 , 4.14, 4.03, 4.18, 4.05, 3.4 ,
#        4.15, 4.25, 3.67, 2.  ])

# %%
list_es2['instant_bookable'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
list_es2.to_csv("Datasets_clean/listing_es2.csv", encoding="utf-8")

# %% [markdown]
# ##### Calendario de reservas - España

# %%
cal_es = pd.concat((cal_bcn, cal_eus, cal_gir, cal_mad, cal_mlg, cal_mlc, cal_mnc, cal_sev, cal_vlc), axis=0)
cal_es
# Out:
#    timestamp_date       city  listing_id        date available    price  \
# 0      2022-12-11  Barcelona       18674  2022-12-11         f  $111.00
# 1      2022-12-11  Barcelona       18674  2022-12-12         f  $111.00
# 2      2022-12-11  Barcelona       18674  2022-12-13         t  $175.00
# 3      2022-12-11  Barcelona       18674  2022-12-14         f  $111.00
# 4      2022-12-11  Barcelona       18674  2022-12-15         f  $111.00
# ..            ...        ...         ...         ...       ...      ...
# 95     2022-12-21   Valencia       55692  2023-03-27         f  $100.00
# 96     2022-12-21   Valencia       55692  2023-03-28         f  $100.00
# 97     2022-12-21   Valencia       55692  2023-03-29         f  $100.00
# 98     2022-12-21   Valencia       55692  2023-03-30         f  $100.00
# 99     2022-12-21   Valencia       55692  2023-03-31         f  $100.00
#
#    adjusted_price  minimum_nights  maximum_nights
# 0         $111.00               2            1125
# ...

# %%
cal_es.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp_date  900 non-null    object
#  1   city            900 non-null    object
#  2   listing_id      900 non-null    int64
#  3   date            900 non-null    object
#  4   available       900 non-null    object
#  5   price           900 non-null    object
#  6   adjusted_price  900 non-null    object
#  7   minimum_nights  900 non-null    int64
#  8   maximum_nights  900 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 70.3+ KB

# %%
cal_es["date"].unique()
# Out:
# array(['2022-12-11', '2022-12-12', '2022-12-13', '2022-12-14',
#        '2022-12-15', '2022-12-16', '2022-12-17', '2022-12-18',
#        '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22',
#        '2022-12-23', '2022-12-24', '2022-12-25', '2022-12-26',
#        '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30',
#        '2022-12-31', '2023-01-01', '2023-01-02', '2023-01-03',
#        '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-07',
#        '2023-01-08', '2023-01-09', '2023-01-10', '2023-01-11',
#        '2023-01-12', '2023-01-13', '2023-01-14', '2023-01-15',
#        '2023-01-16', '2023-01-17', '2023-01-18', '2023-01-19',
#        '2023-01-20', '2023-01-21', '2023-01-22', '2023-01-23',
#        '2023-01-24', '2023-01-25', '2023-01-26', '2023-01-27',
#        '2023-01-28', '2023-01-29', '2023-01-30', '2023-01-31',
#        '2023-02-01', '2023-02-02', '2023-02-03', '2023-02-04',
#        '2023-02-05', '2023-02-06', '2023-02-07', '2023-02-08',
# ...

# %%
cal_es.to_csv("Datasets_clean/calendar_es.csv", encoding="utf-8")

# %% [markdown]
# ##### Reseñas - España

# %%
rev_es = pd.concat((rev_bcn, rev_eus, rev_gir, rev_mad, rev_mlg, rev_mlc, rev_mnc, rev_sev, rev_vlc), axis=0)
rev_es
# Out:
#    timestamp_date       city  listing_id         id        date  reviewer_id  \
# 0      2022-12-11  Barcelona       18674    4808211  2013-05-27      4841196
# 1      2022-12-11  Barcelona       18674   10660311  2014-03-02     11600277
# 2      2022-12-11  Barcelona       18674   41087522  2015-08-04     35231385
# 3      2022-12-11  Barcelona       18674   81000756  2016-06-20     23223644
# 4      2022-12-11  Barcelona       18674  278588962  2018-06-18      4756672
# ..            ...        ...         ...        ...         ...          ...
# 95     2022-12-21   Valencia       95393   87286298  2016-07-19      4878910
# 96     2022-12-21   Valencia       95393   89954291  2016-07-30     55576560
# 97     2022-12-21   Valencia      720307   33336849  2015-05-26      2358065
# 98     2022-12-21   Valencia      720307   34545525  2015-06-09     32416651
# 99     2022-12-21   Valencia      720307   34815271  2015-06-12     34765928
#
# ...

# %%
rev_es.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp_date  900 non-null    object
#  1   city            900 non-null    object
#  2   listing_id      900 non-null    int64
#  3   id              900 non-null    int64
#  4   date            900 non-null    object
#  5   reviewer_id     900 non-null    int64
#  6   reviewer_name   900 non-null    object
#  7   comments        900 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 63.3+ KB

# %%
rev_es.to_csv("Datasets_clean/review_es.csv", encoding="utf-8")
